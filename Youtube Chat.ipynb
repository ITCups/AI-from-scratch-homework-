# %%
# !pip install chat-downloader

from chat_downloader import ChatDownloader

url = 'https://www.youtube.com/watch?v=0n_TiWmFfeg&t=5533s'
chat = ChatDownloader().get_chat(url)       # create a generator
for message in chat:                        # iterate over messages
    print(chat.format(message))             # print the formatted message
# Out:
# Collecting chat-downloader
#   Downloading https://files.pythonhosted.org/packages/e3/0b/0a27a09a403a6c1f9fb349381041ad79af04d98d686ef0f8e76f0b5e9066/chat_downloader-0.0.8-py2.py3-none-any.whl (61kB)
#      |████████████████████████████████| 61kB 3.2MB/s
# Collecting isodate
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 5.3MB/s
# Collecting colorlog
#   Downloading https://files.pythonhosted.org/packages/32/e6/e9ddc6fa1104fda718338b341e4b3dc31cd8039ab29e52fc73b508515361/colorlog-5.0.1-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from chat-downloader) (2.23.0)
# Collecting datetime
#   Downloading https://files.pythonhosted.org/packages/73/22/a5297f3a1f92468cc737f8ce7ba6e5f245fcfafeae810ba37bd1039ea01c/DateTime-4.3-py2.py3-none-any.whl (60kB)
#      |████████████████████████████████| 61kB 6.5MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from chat-downloader) (2019.12.20)
# Collecting argparse
#   Downloading https://files.pythonhosted.org/packages/f2/94/3af39d34be01a24a6e65433d19e107099374224905f1e0cc6bbe1fd22a2f/argparse-1.4.0-py2.py3-none-any.whl
# Collecting docstring-parser
#   Downloading https://files.pythonhosted.org/packages/ce/b0/4d4601b2a25de597cbb84937be42cd238217bebaacde0d75707e6c89b641/docstring_parser-0.7.3.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->chat-downloader) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->chat-downloader) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->chat-downloader) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->chat-downloader) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->chat-downloader) (2020.12.5)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from datetime->chat-downloader) (2018.9)
# Collecting zope.interface
#   Downloading https://files.pythonhosted.org/packages/bb/a7/94e1a92c71436f934cdd2102826fa041c83dcb7d21dd0f1fb1a57f6e0620/zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251kB)
#      |████████████████████████████████| 256kB 27.4MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from zope.interface->datetime->chat-downloader) (56.1.0)
# Building wheels for collected packages: docstring-parser
#   Building wheel for docstring-parser (PEP 517) ... done
#   Created wheel for docstring-parser: filename=docstring_parser-0.7.3-cp37-none-any.whl size=19230 sha256=37961245c7884139ef1ded66c2c56f9f75696f0a6c1913f377217a10854aa9da
#   Stored in directory: /root/.cache/pip/wheels/87/6b/a2/be5c15ac743037f1b006ae4f92a6a81e79a74084cd3ff6fc4c
# Successfully built docstring-parser
# Installing collected packages: isodate, colorlog, zope.interface, datetime, argparse, docstring-parser, chat-downloader
# Successfully installed argparse-1.4.0 chat-downloader-0.0.8 colorlog-5.0.1 datetime-4.3 docstring-parser-0.7.3 isodate-0.6.0 zope.interface-5.4.0
# 2:14 | (Owner) Русская Школа Программирования: Всем привет! Кто уже присоединился к трансляции? Напишите «Привет». Добро пожаловать! 🙂
# 4:18 | Iga: +
# 6:49 | Михаил Меркулов: +
# 8:21 | Илья Наумов: hello
# 8:26 | Максим Цветков: Привет
# 9:58 | andre petrov: +
# 10:06 | Valeron Skripkin: +
# 10:16 | Valeron Skripkin: Всем привет
# 10:29 | Светлана Финагина: привет
# 10:39 | Владислав Саломатин: привет
# 11:15 | Vlad Freezer: привет
# 11:16 | Vila 555: здравия желаю!
# 11:57 | Valeron Skripkin: я очень рад. ведь это моя долгожданная лекция👍👍❤️💜🧡💙💚
# 12:07 | Ganka Nikowa: +
# 13:48 | SUNSHINE SUNSHINE: Всем привет!:goodvibes:
# 15:29 | Andpav: настрой на победу
# 16:53 | Vanysha: всем привет
# 18:09 | Александр БЕДРИК: +
# 18:35 | Александр БЕДРИК: о, есть контакт.... а то ошибка и ошибка, ошибка и ошибка...
# 19:23 | SUNSHINE SUNSHINE: Andpav всмысле
# 22:31 | Александр БЕДРИК: у меня вот такой вопрос: а в ОТЕЧЕСТВЕННОЙ практике ещё не сформировались функциональные роли в DS ?? уже не первый лектор говорит "сейчас я вам объясню что такое ЭмЭльИнженер и ДатаИнженер"
# 22:59 | Andpav: я смотрю с 4 минутной задержкой
# 23:30 | Александр БЕДРИК: ...весь если уже ЕСТЬ (устоялись, сформировались функциональные роли) - значит должны устояться ПОНЯТНЫЕ, привычные определения этих ролей (профессий)
# 24:30 | Александр БЕДРИК: например - "инженер ПЕРВИЧНОЙ обработки данных", "инженер ОБУЧЕНИЯ систем управления", ну и так далее
# 27:05 | Александр БЕДРИК: а то - "бизнес дата саенс эм эль инжиниринга бизнес аналитики"... брррррр!!🤢
# 29:10 | andre petrov: какой у Вас стаж?
# 30:06 | Valeron Skripkin: Дата сантис это аналитик данных или программист?
# 32:43 | Александр БЕДРИК: @Valeron Skripkin - вот я об этом и говорю: Вам скорее всего ответят както вроде "ну это не программист и не аналитег... точнее это аналитег который программирует... ну в общем вы поняли" 😉
# 33:25 | Vila 555: что такое табличные данные?
# 35:19 | Александр БЕДРИК: ну то есть в МАЛЕНЬКОЙ конторе - это будет просто некий АНАЛИТИК, который "за всё" , верно??
# 36:39 | Александр БЕДРИК: ...как бы ЭниКей в сфере "даты" (данных)
# 36:48 | andre petrov: Спасибо! Значить поделитесь опытом?😊
# 39:17 | andre petrov: А правда что практически все данные можно описать в таблицах? Где -то на 3 лекции интересная фраза была...
# 39:23 | Александр БЕДРИК: то есть если коротко МЕТКА - это наличие искомого ПРИЗНАКА КЛАССИФИКАЦИИ, так?
# 42:34 | Александр БЕДРИК: вот Бастрыкин и прославился
# 45:45 | Александр БЕДРИК: антон уточните - что значит "шапочка" над функцией?
# 52:21 | Aji Dahaka: +
# 52:24 | Александр БЕДРИК: +
# 52:34 | Vanysha: +
# 53:09 | Александр БЕДРИК: как понять "свойство производной"?? их... одно?
# 53:19 | andre petrov: ну Вы блин даете!!!😊😊 Я школу забыл...
# 53:49 | Александр БЕДРИК: @andre petrov - а институт??
# 57:23 | Александр БЕДРИК: ПОДОЖДИТЕ - а КАК ещё "задавать" картинки если не представляя их МНОЖЕСТВОМ ЗНАЧЕНИЙ, то бишь кодируя? неужели как-то просто "скармливать" графические файлы что ли?
# 59:16 | andre petrov: @Александр БЕДРИК и институт давно, в 90-х
# 59:33 | Александр БЕДРИК: минуточку! это как раз не свойство - а самое что ни на есть базовое ОПРЕДЕЛЕНИЕ производной 🤭
# 1:01:03 | Александр БЕДРИК: оно РОВНО ТАК и звучит: производная - это скорость изменения функции в зависимости от динамики аргумента
# 1:01:49 | Александр БЕДРИК: точнее - это ФИЗИЧЕСКИЙ смысл
# 1:01:54 | Iga: @Александр БЕДРИК имей совесть..
# 1:05:43 | Александр БЕДРИК: так-так-так... был упомянут ГРАДИЕНТ и алгоритм подбора коэффициента через СПУСК - не докатились ли мы до метода "градиентного спуска"??
# 1:07:35 | Valeron Skripkin: Я не понимаю значение формул. Можно поподробней обьяснить формулы по элементам.
# 1:11:21 | Valeron Skripkin: Спасибо.
# 1:11:24 | andre petrov: То есть в задании надо будет что-предсказать?
# 1:12:42 | Александр БЕДРИК: @andre petrov - я так понял надо будет изложить написанное формулами в виде кода, то есть разложить по процедурам Пайтона
# 1:13:00 | Александр БЕДРИК: а что ИМЕННО - ну да, наверно какая-то простейшая регрессия
# 1:13:33 | Valeron Skripkin: Спасибо огромное!
# 1:17:06 | andre petrov: Ясненько
# 1:18:21 | Лёха X: А будет этот набор в дз повторён?
# 1:18:33 | Лёха X: Именно в самой форме
# 1:18:56 | Максим Цветков: Экрана нет
# 1:18:59 | Евгений Бабинцев: экрана нет
# 1:19:05 | Iga: Рабочий стол не видно!
# 1:19:10 | Valeron Skripkin: можете включить демонстрацию
# 1:19:24 | Лёха X: Нет,вы не включили наверное трансляцию экрана
# 1:19:24 | andre petrov: нету
# 1:19:42 | Valeron Skripkin: есть
# 1:20:20 | Valeron Skripkin: можете показать как импортировать данные.
# 1:29:55 | Iga: Почему в признаке Синий несколько единиц?
# 1:31:17 | Iga: (в показанной таблице)
# 1:32:51 | Valeron Skripkin: А можно это выполнить в XL?
# 1:34:17 | Iga: @Valeron Skripkin если ты из fit_predict, точно НЕТ!)))
# 1:34:27 | Олег Денисенко: Если какой-то столбец данными мы считаем не таким важным, как остальные, Стоит ли его кодировать не нулем и единицей, а Например 0 и 0,2?
# 1:35:29 | Vlad Freezer: а примерно хотя бы, какие новые признаки могут создаться?
# 1:46:48 | andre petrov: А презентацию скините? Формулы познавательно?
# 1:47:04 | Valeron Skripkin: Покажите пожайлуста как это сделать
# 2:00:22 | Aji Dahaka: А почему GRU, а не LSTM?
# 2:02:36 | Iga: В данном словаре смысл слова влияет на присваемое цифровое значение (большое или малое значение) или цифра это просто id слова?
# 2:02:37 | Aji Dahaka: А если Attention добавить?
# 2:03:46 | Vlad Freezer: а зачем в видеокарту загружать?
# 2:09:12 | Valeron Skripkin: Покажите пожайлуста как сделать ДЗ на XL
# 2:09:19 | Михаил Никонец: "переобучаемость" модели здесь может возникнуть?
# 2:09:52 | Valeron Skripkin: где можно взять коды
# 2:11:53 | (Owner) Русская Школа Программирования: Ссылка на форму домашнего задания - https://forms.gle/ZAtxW6v3xmnYMwjF8
# 2:13:02 | andre petrov: Исходные данные будут в задании и их нужно подгрузить?
# 2:14:03 | Valeron Skripkin: где можно взять коды?
# 2:14:34 | Aji Dahaka: Почему GRU, а не LSTM использовали? Из-за того, что GRU быстрее?
# 2:15:26 | Михаил Никонец: данные для прогона 2-го задания берем те же?
# 2:16:09 | Iga: На каком уровне специалиста Data Science (например, в Мегафон) нужно досконально понимать, как работает та или иная нейронная сеть?
# 2:16:11 | Iga: Или внутрь НС никто не смотрит и выбор конкретной модели для какой-либо задачи идёт на тестовых наборах данных?
# 2:17:14 | andre petrov: ясно, спасибо
# 2:17:55 | Valeron Skripkin: Коды нужно будет выбрать из представленных данных?
# 2:21:02 | andre petrov: Про книжки ясно, а каких авторов? И есть они в инете?
# 2:21:18 | Valeron Skripkin: коды которые ну4ужно будет выбрать из данных которые нам дадут админы?
# 2:21:40 | Iga: Спасибо за очень ценный материал!
# 2:21:55 | Valeron Skripkin: где можно взять коды
# 2:22:05 | Valeron Skripkin: пожалуйста скажите
# 2:22:12 | Vlad Freezer: спасибо
# 2:22:19 | Максим Цветков: Спасибо большое, до свидания!
# 2:22:23 | Михаил Никонец: спасибо огромное! очень познавательно!
# 2:22:25 | Maria Lebedeva: Спасибо!
# 2:22:36 | andre petrov: Спасибо
# 2:22:45 | taya taya: спасибо огромное за лекцию!
# 2:22:51 | Iga: @Valeron Skripkin Прикрепляют ссылки обычно после занятия.
